# %% [markdown]
# ![Self Check Exercises check mark image](files/art/check.png)
# # 6.4 Objects Natural Intro to Data Science: Dynamic Visualizations Self Check

# %% [markdown]
# ### 6.4 Checkpoint Snippets

# %% [markdown]
# **(Fill-In)** As we toss a coin an increasing number of times, we expect the percentages of heads and tails to become closer to 50% each. This is a manifestation of `_____`.
#
# **Answer:** the law of large numbers.

# %% [markdown]
# ### 6.4.1 Checkpoint Snippets

# %% [markdown]
# **(Fill-In)** In an animation, a(n) `_____` specifies everything that should change during one update.
#
# **Answer:** animation frame.

# %% [markdown]
# **(True/False)** Generally, displaying fewer frames per second yields smoother animation.
#
# **Answer:** False. Generally, displaying more yields smoother animation.

# %% [markdown]
# **(True/False)** The actual number of frames per second is affected only by the millisecond interval between animation frames.
#
# **Answer:** False. The actual number of frames per second can also be affected by the amount of work performed in each frame, the speed of your computer's processor and the workload currently on your machine.

# %% [markdown]
# ### 6.4.3 Checkpoint Snippets

# %% [markdown]
# **(Fill-In)** An object of the Matplotlib `_____` module's `FuncAnimation` class dynamically updates a visualization.
#
# **Answer:** `animation`.

# %% [markdown]
# **(Fill-In)** `FuncAnimation`'s `_____` keyword argument enables you to pass custom arguments to the function that's called once per animation frame.
#
# **Answer:** `fargs`.

# %% [markdown]
# **(Code)** Modify `RollDieDynamic.py` to use the `functools` module's `partial` function as described in Section 6.4.3.

# %%
##########################################################################
# (C) Copyright 1992-2026 by Deitel & Associates, Inc. and               #
# Pearson Education, Inc. All Rights Reserved.                           #
#                                                                        #
# DISCLAIMER: The authors and publisher of this book have used their     #
# best efforts in preparing the book. These efforts include the          #
# development, research, and testing of the theories and programs        #
# to determine their effectiveness. The authors and publisher make       #
# no warranty of any kind, expressed or implied, with regard to these    #
# programs or to the documentation contained in these books. The authors #
# and publisher shall not be liable in any event for incidental or       #
# consequential damages in connection with, or arising out of, the       #
# furnishing, performance, or use of these programs.                     #
##########################################################################
